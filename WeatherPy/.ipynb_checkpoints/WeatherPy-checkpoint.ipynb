# %% [markdown]
# # WeatherPy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from datetime import date
import os
import sys
import random
from scipy.stats import linregress
from scipy.stats import normaltest
import json
import gmaps
import csv
from citipy import citipy

#Include api directory in path
module_path = os.path.abspath(os.path.join('..')) 
if module_path not in sys.path:
    sys.path.append(module_path + "\\api")
    
    
# Import API key.  Update weather api key in api_keys.py file 
from api_keys import weather_api_key

weather_key = weather_api_key

weather_base_url = "http://api.openweathermap.org/data/2.5/weather?"


# Output File (CSV)

output_data_file = "../output_data/"

current_date = date.today().strftime("%m/%d/%Y")

# %% [markdown]
# ## Genereate Random Cities

# %%
# Incorporated citipy to determine city based on latitude and longitude
#from citipy import citipy

#Create function for resuse in case ever wanting to create sample cities in future.
def gen_rand_cities(dict):
    coord_list = []
    min_lat = dict["lat_min"]
    max_lat = dict["lat_max"]
    min_long = dict["long_min"]
    max_long = dict["long_max"]
    samp_size = dict["samp_size"]
    x = 0
    city = []
    country = []
    while x < samp_size:
 
        lat_rand = min_lat + (max_lat - min_lat) * random.random()
        long_rand = min_long + (max_long - min_long) * random.random() 
        city_obj = citipy.nearest_city(lat_rand, long_rand) 
        #Don't duplicate city names
        if city_obj.city_name not in city:                  
            city.append(city_obj.city_name)
            country.append(city_obj.country_code)
            #print(f"{x} {city_obj.city_name} {city_obj.country_code}")
            x = x + 1
            
              
    funct_df = pd.DataFrame ( {
                              "city": city,
                              "country":country,             
                             })
    return(funct_df)

#Set dictionary to pass into function that will generate city list by 
#lattitude/longitude ranges
city_geo_params = {"lat_min":-90,
                   "lat_max":90,
                   "long_min":-180,
                   "long_max":180,
                   "samp_size":500};



city_df = gen_rand_cities(city_geo_params)     

len(city_df)
# Out:
# 500

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Initialize cities that will create data frame
cities = []
countries = []
lattitudes = []
longitudes = []
max_temps = []
humidities = []
cloudiness = []
windspeeds = []
countries = []
dates = []


#User itterrows to loop through data frame calling weather api to grab stats when city exists.
for index, row in city_df.iterrows():
    city = row['city']
    country = row['country'].upper()
    params = {"appid": weather_key, "q": city + ',' + country, "units":"imperial"}
    #Exception block to handle when city can't be found.
    try:
        response = requests.get(weather_base_url,params=params).json()
        lattitudes.append(response["coord"]["lat"])
        longitudes.append(response["coord"]["lon"])
        max_temps.append(response["main"]["temp_max"])
        humidities.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        windspeeds.append(response["wind"]["speed"])
        countries.append(country)
        cities.append(city)
        dates.append(response["dt"])
        print(f'{index}- {city} ({response["coord"]["lat"]}:{response["coord"]["lon"]})')                              
    except:
        print(f'{city} ({country}) Not Found')
# Out:
# 0- ushuaia (-54.8:-68.3)
# 1- provideniya (64.3833:-173.3)
# 2- torbay (47.6666:-52.7314)
# 3- otane (-39.8833:176.6333)
# belushya guba (RU) Not Found
# barentsburg (SJ) Not Found
# 6- thompson (55.7435:-97.8558)
# 7- jajce (44.3422:17.2656)
# 8- urucara (-2.5364:-57.76)
# 9- port alfred (-33.5906:26.891)
# 10- vila velha (-20.3297:-40.2925)
# 11- olga (43.7444:135.2892)
# yaan (CN) Not Found
# 13- busselton (-33.65:115.3333)
# 14- kwinana (-32.25:115.7667)
# 15- hobart (-42.8794:147.3294)
# 16- etchojoa (26.9167:-109.6333)
# 17- ponta do sol (17.1994:-25.0919)
# 18- portland (-38.3333:141.6)
# 19- saint george (32.3817:-64.6781)
# 20- tuktoyaktuk (69.4541:-133.0374)
# 21- malinyi (-8.9333:36.1333)
# 22- dustlik (40.5247:68.0358)
# 23- luderitz (-26.6481:15.1594)
# 24- liepaja (56.5419:21.0367)
# 25- los llanos de aridane (28.6585:-17.9182)
# 26- jamestown (-15.9387:-5.7168)
# 27- pevek (69.7008:170.3133)
# 28- vao (-22.6667:167.4833)
# 29- severo-kurilsk (50.6789:156.125)
# 30- sri aman (1.2376:111.4621)
# 31- nabire (-3.3667:135.4833)
# 32- husavik (66.0449:-17.3389)
# 33- saint-augustin (51.226:-58.6502)
# 34- hermanus (-34.4187:19.2345)
# 35- rikitea (-23.1203:-134.9692)
# 36- qaanaaq (77.484:-69.3632)
# 37- tuatapere (-46.1333:167.6833)
# asau (TV) Not Found
# 39- nikolskoye (59.7035:30.7861)
# tubruq (LY) Not Found
# 41- klaksvik (62.2266:-6.589)
# 42- khatanga (71.9667:102.5)
# 43- salalah (17.0151:54.0924)
# sentyabrskiy (RU) Not Found
# 45- gdov (58.7406:27.8122)
# 46- oda (35.1833:132.5)
# 47- azare (11.6765:10.1948)
# 48- new norfolk (-42.7826:147.0587)
# 49- ancud (-41.8697:-73.8203)
# 50- bredasdorp (-34.5322:20.0403)
# 51- kamiiso (41.8167:140.65)
# 52- puerto ayora (-0.7393:-90.3518)
# 53- punta arenas (-53.15:-70.9167)
# avera (PF) Not Found
# mataura (PF) Not Found
# 56- butaritari (3.0707:172.7902)
# 57- lebu (-37.6167:-73.65)
# 58- salinopolis (-0.6136:-47.3561)
# 59- berlevag (70.8578:29.0864)
# 60- padang (-0.9492:100.3543)
# 61- denpasar (-8.65:115.2167)
# 62- vaini (-21.2:-175.2)
# 63- grindavik (63.8424:-22.4338)
# 64- caravelas (-17.7125:-39.2481)
# 65- carnarvon (-24.8667:113.6333)
# 66- jumla (29.2747:82.1838)
# airai (PW) Not Found
# illoqqortoormiut (GL) Not Found
# 69- tautira (-17.7333:-149.15)
# 70- tiksi (71.6872:128.8694)
# 71- outjo (-20.1167:16.15)
# 72- vestmanna (62.1564:-7.1664)
# 73- kapaa (22.0752:-159.319)
# 74- tamworth (-31.1:150.9333)
# 75- cape town (-33.9258:18.4232)
# 76- saint-ambroise (48.5501:-71.3324)
# 77- arraial do cabo (-22.9661:-42.0278)
# 78- atuona (-9.8:-139.0333)
# 79- bambanglipuro (-7.95:110.2833)
# 80- victoria (-4.6167:55.45)
# 81- port elizabeth (-33.918:25.5701)
# 82- kaitangata (-46.2817:169.8464)
# 83- tucuman (-26.8241:-65.2226)
# 84- zhigansk (66.7697:123.3711)
# 85- vydrino (51.485:104.8461)
# 86- faanui (-16.4833:-151.75)
# 87- gunjur (13.2019:-16.7339)
# 88- chokurdakh (70.6333:147.9167)
# aras (NO) Not Found
# 90- ischia (40.7342:13.9471)
# 91- kalawit (8.0667:122.5167)
# 92- lewiston (44.1003:-70.2148)
# 93- yar-sale (66.8333:70.8333)
# 94- barcelona (10.1333:-64.7)
# 95- olafsvik (64.8945:-23.7142)
# 96- albany (-35.0169:117.8917)
# 97- pisco (-13.7:-76.2167)
# 98- touros (-5.1989:-35.4608)
# 99- sinnamary (5.3833:-52.95)
# 100- zurrieq (35.8311:14.4742)
# 101- fortuna (40.5982:-124.1573)
# 102- mar del plata (-38.0023:-57.5575)
# 103- sola (-13.8833:167.55)
# 104- palu (-0.8917:119.8707)
# 105- araouane (18.9048:-3.5265)
# abu samrah (QA) Not Found
# 107- puerto rico (1.9142:-75.145)
# 108- santa isabel do rio negro (-0.4139:-65.0192)
# 109- madaoua (14.073:5.96)
# 110- camden (39.7835:-74.9663)
# 111- acarau (-2.8856:-40.12)
# 112- seryshevo (51.0933:128.3786)
# 113- san jose (16.9833:-89.9)
# 114- qui nhon (13.7667:109.2333)
# 115- kieta (-6.2167:155.6333)
# 116- cherskiy (68.75:161.3)
# 117- dir (35.2058:71.8756)
# tumannyy (RU) Not Found
# 119- sitka (57.0531:-135.33)
# 120- vardo (70.3705:31.1107)
# 121- barrow (71.2906:-156.7887)
# 122- bethel (41.3712:-73.414)
# taolanaro (MG) Not Found
# 124- avarua (-21.2078:-159.775)
# 125- kodiak (57.79:-152.4072)
# attawapiskat (CA) Not Found
# 127- walvis bay (-22.9575:14.5053)
# 128- derzhavinsk (51.1:66.3167)
# 129- arlit (18.7369:7.3853)
# 130- hervey bay (-25.2986:152.8535)
# 131- hithadhoo (-0.6:73.0833)
# 132- castro (-42.4721:-73.7732)
# 133- bengkulu (-3.8004:102.2655)
# 134- port macquarie (-31.4333:152.9167)
# 135- lagoa (39.05:-27.9833)
# 136- svetlyy (54.675:20.1347)
# 137- srednekolymsk (67.45:153.6833)
# 138- mount gambier (-37.8333:140.7667)
# 139- dudinka (69.4058:86.1778)
# kamenskoye (RU) Not Found
# 141- vanimo (-2.6741:141.3028)
# 142- chapada dos guimaraes (-15.4606:-55.7497)
# 143- saskylakh (71.9167:114.0833)
# 144- leh (34.1667:77.5833)
# 145- luanda (-8.8368:13.2343)
# 146- east london (-33.0153:27.9116)
# 147- gaozhou (21.9392:110.8461)
# 148- yellowknife (62.456:-114.3525)
# 149- jalu (29.0331:21.5482)
# codrington (AG) Not Found
# 151- cabinda (-5.55:12.2)
# afanasyevo (RU) Not Found
# 153- allende (25.2833:-100.0167)
# lasa (CN) Not Found
# 155- naze (28.3667:129.4833)
# 156- bluff (-46.6:168.3333)
# 157- berdigestyakh (62.0989:126.6992)
# 158- mehamn (71.0357:27.8492)
# 159- tecoanapa (16.5167:-98.75)
# karaul (RU) Not Found
# 161- pasinler (39.9803:41.6764)
# 162- the valley (18.217:-63.0578)
# 163- christchurch (-43.5333:172.6333)
# amderma (RU) Not Found
# 165- dolores (12.0371:125.4825)
# 166- nome (64.5011:-165.4064)
# 167- yeppoon (-23.1333:150.7333)
# 168- okato (-39.2:173.8833)
# saleaula (WS) Not Found
# 170- ahipara (-35.1667:173.1667)
# 171- pital (10.4506:-84.2741)
# marcona (PE) Not Found
# 173- kalmunai (7.4167:81.8167)
# 174- nipawin (53.3668:-104.0009)
# 175- clyde river (70.4692:-68.5914)
# 176- ormara (25.2088:64.6357)
# 177- tumpat (6.1978:102.171)
# karakendzha (TJ) Not Found
# 179- port blair (11.6667:92.75)
# 180- alice springs (-23.7:133.8833)
# samusu (WS) Not Found
# 182- blyth (55.1271:-1.5086)
# 183- praia (14.9215:-23.5087)
# 184- estelle (29.8458:-90.1067)
# 185- waddan (29.1614:16.139)
# 186- norman wells (65.282:-126.8329)
# 187- chapais (49.7834:-74.8492)
# 188- kavieng (-2.5744:150.7967)
# nizhneyansk (RU) Not Found
# 190- aykhal (66:111.5)
# 191- paitan (6.6597:124.8714)
# 192- athabasca (54.7169:-113.2854)
# 193- vagay (57.9375:69.0217)
# 194- verkhoyansk (67.5447:133.385)
# 195- poum (-20.2333:164.0167)
# 196- zalantun (48:122.7167)
# 197- waiblingen (48.8324:9.3164)
# 198- ustye (59.6304:39.736)
# 199- dosso (13.049:3.1937)
# chagda (RU) Not Found
# 201- nkayi (-4.1841:13.2884)
# 202- mahebourg (-20.4081:57.7)
# 203- ribeira grande (38.5167:-28.7)
# ozgon (KG) Not Found
# 205- esperance (-33.8667:121.9)
# 206- brae (60.3964:-1.353)
# 207- takaka (-40.85:172.8)
# 208- banikoara (11.2985:2.4386)
# 209- hilo (19.7297:-155.09)
# 210- peace river (56.2501:-117.286)
# 211- kouango (4.9934:19.9619)
# 212- hasaki (35.7333:140.8333)
# buariki (KI) Not Found
# 214- saint-philippe (-21.3585:55.7679)
# 215- mantua (22.2889:-84.2844)
# 216- parkes (-33.1333:148.1833)
# 217- kadoma (-18.3333:29.9153)
# 218- mocuba (-16.8392:36.9856)
# 219- manggar (-2.8833:108.2667)
# mys shmidta (RU) Not Found
# 221- saint marys (30.7305:-81.5465)
# 222- dikson (73.5069:80.5464)
# 223- orange cove (36.6244:-119.3137)
# 224- upernavik (72.7868:-56.1549)
# 225- constitucion (23.9912:-104.6749)
# 226- teahupoo (-17.8333:-149.2667)
# 227- isfana (39.8386:69.5306)
# 228- shushenskoye (53.325:91.9356)
# 229- longyearbyen (78.2186:15.6401)
# banmo (MM) Not Found
# 231- horta (38.5333:-28.6333)
# 232- torez (48.0388:38.5969)
# 233- santa marta (11.2408:-74.199)
# umzimvubu (ZA) Not Found
# 235- saint-georges (3.9:-51.8)
# 236- artyom (40.4723:50.333)
# 237- santa cruz (10.2605:-85.5851)
# 238- kruisfontein (-34.0033:24.7314)
# 239- pangnirtung (66.1451:-65.7125)
# 240- merauke (-8.4667:140.3333)
# 241- kapit (2.0167:112.9333)
# 242- hachinohe (40.5:141.5)
# stoyba (RU) Not Found
# 244- bilma (18.6853:12.9164)
# 245- boa vista (2.8197:-60.6733)
# 246- svetlogorsk (54.9399:20.1548)
# 247- tammisaari (59.9736:23.4339)
# 248- georgetown (-7.9333:-14.4167)
# 249- vila franca do campo (37.7167:-25.4333)
# 250- bardiyah (31.7561:25.0865)
# 251- petropavlovsk-kamchatskiy (53.0452:158.6483)
# 252- seoul (37.5683:126.9778)
# 253- harrisburg (40.2737:-76.8844)
# 254- tias (28.9611:-13.645)
# 255- mandalgovi (45.7625:106.2708)
# 256- vostok (46.4856:135.8833)
# 257- karratha (-20.7377:116.8463)
# 258- chicama (-7.8447:-79.1469)
# 259- guerrero negro (27.9769:-114.0611)
# 260- porto walter (-8.2686:-72.7439)
# 261- moshupa (-24.7782:25.4155)
# 262- bambous virieux (-20.3428:57.7575)
# 263- kolosovka (56.4678:73.611)
# hillsborough (GD) Not Found
# 265- zhanakorgan (43.9098:67.2495)
# 266- plouzane (48.3833:-4.6167)
# 267- gunnedah (-30.9833:150.25)
# 268- moerai (-22.4333:-151.3333)
# 269- havoysund (70.9963:24.6622)
# 270- peleduy (59.6289:112.7406)
# lolua (TV) Not Found
# 272- valkeala (60.9401:26.7979)
# tsihombe (MG) Not Found
# 274- saint-pierre (46.7654:-56.1695)
# 275- tumsar (21.3833:79.7333)
# 276- hanmer springs (-42.5167:172.8167)
# 277- ilulissat (69.2167:-51.1)
# 278- broome (-17.9667:122.2333)
# 279- loding (67.3:14.75)
# 280- kahului (20.8947:-156.47)
# 281- gilbues (-9.8317:-45.3439)
# 282- san cristobal (-0.9045:-89.6174)
# 283- saldanha (-33.0117:17.9442)
# 284- deputatskiy (69.3:139.9)
# 285- batagay (67.6333:134.6333)
# 286- istisu (40.9457:48.0738)
# 287- kyren (51.6828:102.1408)
# grand river south east (MU) Not Found
# 289- cabo san lucas (22.8909:-109.9124)
# 290- mahon (39.8885:4.2658)
# 291- zaria (11.1113:7.7227)
# 292- umm kaddadah (13.6017:26.6876)
# 293- tagusao (9.1924:117.8141)
# 294- nogent-le-rotrou (48.3333:1)
# 295- unity (52.4501:-109.1682)
# sumbawa (ID) Not Found
# 297- port hedland (-20.3167:118.5667)
# 298- neftcala (39.3742:49.2472)
# 299- loukhi (66.0764:33.0381)
# 300- tasiilaq (65.6145:-37.6368)
# 301- tosya (41.0155:34.0401)
# 302- manokwari (-0.8667:134.0833)
# 303- harer (9.3094:42.1258)
# 304- qiongshan (20.0058:110.3542)
# 305- komsomolskiy (43.9783:46.6985)
# 306- fairbanks (64.8378:-147.7164)
# ksenyevka (RU) Not Found
# 308- waitati (-45.75:170.5667)
# 309- aktash (50.3:87.7333)
# kadykchan (RU) Not Found
# 311- marienburg (5.8469:-55.0216)
# 312- arman (59.7:150.1667)
# 313- lompoc (34.6391:-120.4579)
# 314- san luis (-33.295:-66.3356)
# 315- manono (-7.3:27.4167)
# 316- colares (38.7992:-9.4469)
# 317- wobulenzi (0.7283:32.5122)
# 318- anadyr (64.75:177.4833)
# 319- petukhovo (55.0692:67.9019)
# 320- barcelos (-0.9747:-62.9242)
# 321- kailua (21.4022:-157.7394)
# 322- san patricio (19.2167:-104.7)
# 323- pochutla (15.7432:-96.4661)
# 324- gorontalo (0.5412:123.0595)
# 325- kenai (60.5544:-151.2583)
# 326- garowe (8.4054:48.4845)
# 327- qeshm (26.9581:56.2719)
# 328- karema (-6.8205:30.4389)
# 329- isangel (-19.55:169.2667)
# 330- balkhash (46.844:74.9804)
# 331- buala (-8.145:159.5921)
# 332- black river (18.0264:-77.8487)
# 333- samarai (-10.6167:150.6667)
# 334- ilesha (7.1371:5.2583)
# 335- taoudenni (22.6783:-3.9836)
# 336- cidreira (-30.1811:-50.2056)
# 337- ibirataia (-14.0669:-39.6406)
# 338- la ronge (55.1001:-105.2842)
# 339- chuy (-33.6971:-53.4616)
# 340- talagang (32.9297:72.4158)
# 341- marsa matruh (31.3525:27.2453)
# 342- key largo (25.0865:-80.4473)
# 343- soyo (-6.1349:12.3689)
# 344- ayan (56.45:138.1667)
# 345- sampit (-2.5333:112.95)
# 346- kamaishi (39.2667:141.8833)
# 347- tual (-5.6667:132.75)
# 348- sabang (5.8933:95.3214)
# 349- vestmannaeyjar (63.4427:-20.2734)
# 350- maniitsoq (65.4167:-52.9)
# 351- paptalaya (15.5:-84.3167)
# 352- xining (36.6167:101.7667)
# 353- preobrazheniye (42.9019:133.9064)
# 354- buckie (57.6757:-2.9624)
# 355- ryotsu (38.0833:138.4333)
# scottsburgh (ZA) Not Found
# taburi (PH) Not Found
# 358- melhus (63.2855:10.2781)
# 359- ialibu (-6.2821:143.9935)
# 360- burhaniye (39.5004:26.9727)
# 361- jatiroto (-7.8833:111.1167)
# 362- songea (-10.6833:35.65)
# 363- korla (41.7597:86.1469)
# 364- nanortalik (60.1432:-45.2371)
# 365- matagami (49.7502:-77.6328)
# 366- maraba (-5.3686:-49.1178)
# 367- uppsala (60:17.75)
# tidore (ID) Not Found
# 369- naryan-mar (67.6713:53.087)
# 370- ofunato (39.0717:141.7167)
# 371- khash (28.2211:61.2158)
# kachikau (BW) Not Found
# 373- mancora (-4.1078:-81.0475)
# 374- mirador (-6.3708:-44.3631)
# 375- salvacion (7.9833:126.1333)
# 376- alexandria (31.2156:29.9553)
# lata (SB) Not Found
# mudyuga (RU) Not Found
# cheuskiny (RU) Not Found
# 380- prince rupert (54.3161:-130.3201)
# nguiu (AU) Not Found
# 382- hovd (48.0056:91.6419)
# 383- karasuk (53.7377:78.0403)
# naftah (TN) Not Found
# kuche (CN) Not Found
# 386- troitsko-pechorsk (62.7084:56.1964)
# 387- flin flon (54.7682:-101.865)
# 388- narsaq (60.9167:-46.05)
# 389- roald (62.5833:6.1333)
# 390- vanderhoof (54.0166:-124.0198)
# 391- tambopata (-12.7333:-69.1833)
# 392- belmonte (-15.8631:-38.8828)
# 393- ewo (-0.8725:14.8206)
# 394- manaus (-3.1019:-60.025)
# requena (PE) Not Found
# 396- slavutych (51.5196:30.7343)
# 397- nantucket (41.2835:-70.0995)
# 398- jining (35.405:116.5814)
# 399- harnai (30.1005:67.9374)
# 400- novikovo (51.1537:37.8879)
# 401- guilin (25.2819:110.2864)
# 402- ciudad del maiz (22.4:-99.6)
# 403- katsuura (35.1333:140.3)
# 404- whitehorse (60.7161:-135.0538)
# 405- alekseyevsk (57.8406:108.3492)
# 406- bowen (-20.0167:148.2333)
# 407- necochea (-38.5473:-58.7368)
# 408- mwingi (-0.9344:38.0601)
# 409- east massapequa (40.6734:-73.4365)
# 410- sorland (67.667:12.6934)
# 411- sabancuy (18.9667:-91.1833)
# 412- tucuma (-0.1833:-50.05)
# 413- killorglin (52.1:-9.7833)
# 414- bogandinskiy (56.8937:65.8938)
# 415- goundam (16.4145:-3.6708)
# 416- port moresby (-9.4431:147.1797)
# 417- catamarca (-28.4696:-65.7852)
# 418- mount isa (-20.7333:139.5)
# babanusah (SD) Not Found
# 420- soverato (38.685:16.5499)
# 421- porto novo (17.0197:-25.0647)
# 422- baculin (7.4525:126.5842)
# 423- coahuayana (18.7333:-103.6833)
# 424- smithers (54.7804:-127.1743)
# 425- antibes (43.5624:7.1278)
# 426- chunskiy (56.0815:99.6342)
# 427- bihoro (43.8228:144.1044)
# vaitupu (WF) Not Found
# 429- pampa (35.5362:-100.9599)
# 430- bukama (-9.2:25.85)
# 431- vartej (21.7333:72.0667)
# 432- niscemi (37.1486:14.3913)
# 433- bogotol (56.2078:89.5342)
# 434- cockburn town (24.0333:-74.5167)
# 435- zalesovo (53.9939:84.7431)
# 436- clarence town (23.1:-74.9833)
# 437- bam (29.106:58.357)
# 438- dhidhdhoo (6.8833:73.1)
# holme (NO) Not Found
# 440- bobon (12.5246:124.5636)
# 441- tura (64.2833:100.25)
# 442- olinda (-8.0089:-34.8553)
# 443- itoman (26.1247:127.6694)
# 444- asekeyevo (53.5742:52.7972)
# 445- blackfoot (43.1905:-112.345)
# 446- lucapa (-8.4192:20.7447)
# 447- nhulunbuy (-12.2333:136.7667)
# 448- tam ky (15.5667:108.4833)
# 449- riyadh (24.6877:46.7219)
# 450- katherine (-14.4667:132.2667)
# 451- rawson (-43.3002:-65.1023)
# 452- bubaque (11.2833:-15.8333)
# 453- radomsko (51.0671:19.4448)
# 454- pingliang (35.5392:106.6861)
# 455- bumba (2.1833:22.4667)
# 456- nelson bay (-32.7167:152.15)
# 457- champasak (14.75:106)
# 458- kinablangan (7.6947:126.5503)
# 459- geraldton (-28.7667:114.6)
# 460- fare (-16.7:-151.0167)
# warqla (DZ) Not Found
# 462- coquimbo (-29.9533:-71.3436)
# teneguiban (PH) Not Found
# 464- hualmay (-11.0964:-77.6139)
# 465- omsukchan (62.5333:155.8)
# 466- ust-koksa (50.2696:85.6108)
# 467- nemuro (43.3236:145.575)
# 468- zabol (31.0287:61.5012)
# 469- hirara (24.8:125.2833)
# 470- rio grande (-32.035:-52.0986)
# 471- miri (4.4148:114.0089)
# 472- warrington (30.3841:-87.275)
# 473- harper (4.375:-7.7169)
# 474- ponnani (10.767:75.9252)
# payo (PH) Not Found
# 476- weinan (34.5036:109.5089)
# 477- las palmas (28.4204:-14.0131)
# 478- alugan (12.2188:125.4808)
# 479- hay river (60.8156:-115.7999)
# 480- redding (40.5865:-122.3917)
# 481- sal (32.5694:35.9119)
# 482- aklavik (68.2191:-135.0107)
# 483- praia da vitoria (38.7333:-27.0667)
# 484- manta (-0.95:-80.7333)
# 485- price (39.5994:-110.8107)
# 486- coatepec harinas (18.8949:-99.7215)
# 487- ponta delgada (37.7333:-25.6667)
# 488- saint-louis (-21.2667:55.4167)
# 489- along (28.1667:94.7667)
# 490- paita (-5.0892:-81.1144)
# 491- pierre (44.3683:-100.351)
# 492- pangody (65.85:74.4859)
# 493- merke (42.8728:73.1786)
# 494- half moon bay (37.4636:-122.4286)
# 495- preili (56.2944:26.7246)
# meyungs (PW) Not Found
# 497- talnakh (69.4865:88.3972)
# 498- panjab (34.388:67.0233)
# 499- poya (-21.35:165.15)

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Credate data frame that will hold data imported from cities.csv file produced in above cell
city_api_df = pd.DataFrame(
                            {"City": cities,
                             "Lat" : lattitudes,
                             "Lng" : longitudes,
                             "Max Temp":max_temps,
                             "Humidity": humidities,
                             "Cloudiness": cloudiness,
                             "Wind Speed": windspeeds,
                             "Country":countries,
                             "Date": dates
                             })

# %%
city_api_df.to_csv(output_data_file + "cities.csv")
city_api_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  442.000000  442.000000  442.000000  442.000000  442.000000  442.000000
# mean    20.244342   22.492476   50.338281   74.361991   52.984163    9.276244
# std     33.632755   93.279562   31.789913   19.329350   38.553755    6.823483
# min    -54.800000 -175.200000  -43.910000   11.000000    0.000000    0.400000
# 25%     -6.708075  -58.715150   28.400000   66.000000   14.000000    4.022500
# 50%     22.784600   24.908950   60.800000   78.000000   56.500000    7.630000
# 75%     50.148050  110.285625   76.065000   89.000000   90.000000   12.727500
# max     78.218600  177.483300  102.200000  100.000000  100.000000   44.400000
#
#                Date
# count  4.420000e+02
# mean   1.612330e+09
# std    1.580508e+02
# min    1.612330e+09
# 25%    1.612330e+09
# 50%    1.612330e+09
# 75%    1.612331e+09
# max    1.612331e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
clean_city_data = city_api_df.loc[city_api_df["Humidity"] < 100 ]
clean_city_data.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  432.000000  432.000000  432.000000  432.000000  432.000000  432.000000
# mean    20.070274   23.101291   50.362546   73.768519   53.039352    9.323704
# std     33.772987   93.515307   31.958326   19.149119   38.508092    6.840470
# min    -54.800000 -175.200000  -43.910000   11.000000    0.000000    0.400000
# 25%     -7.436175  -58.671850   28.365000   65.000000   14.000000    4.067500
# 50%     22.344450   25.492800   60.870000   78.000000   56.500000    7.665000
# 75%     50.394725  110.303350   75.955000   88.000000   90.000000   12.872500
# max     78.218600  177.483300  102.200000   99.000000  100.000000   44.400000
#
#                Date
# count  4.320000e+02
# mean   1.612330e+09
# std    1.588001e+02
# min    1.612330e+09
# 25%    1.612330e+09
# 50%    1.612330e+09
# 75%    1.612331e+09
# max    1.612331e+09

# %%
k2, pval = normaltest(clean_city_data["Humidity"])

if pval < .05:
    print(f'P Value of Humdity is {pval} suggests data is not normally distributed about the mean.')
else:
    print(f'P Value of Humidity is {pval} suggests data is normally distributed about the mean.')
# Out:
# P Value of Humdity is 1.62792994082427e-16 suggests data is not normally distributed about the mean.

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
ax = plt
ax.figure(figsize=(12,6))
ylim_top = clean_city_data["Max Temp"].max() + 10
ylim_bottom = clean_city_data["Max Temp"].min() - 5
ax.scatter(x=clean_city_data["Lat"], y=clean_city_data["Max Temp"], marker='o')
ax.ylim(ylim_bottom,ylim_top)
ax.ylabel("Temperature (F)",fontsize=14)
ax.xlabel("Lattitude",fontsize=14)
ax.title(f"Lattitude  vs. Max Temperature ({current_date}) ",fontsize=15)
ax.plot()
ax.savefig(output_data_file + "lattitude_vs_max_temp.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
ax1 = plt
ax1.figure(figsize=(12,6))
ylim_top = clean_city_data["Humidity"].max() + 10
ylim_bottom = clean_city_data["Humidity"].min() - 5
x_vals = clean_city_data["Lat"]
y_vals = clean_city_data["Humidity"]
ax1.scatter(x=x_vals, y=y_vals, marker='o')
ax1.ylim(ylim_bottom,ylim_top)
ax1.ylabel("Humidity (%)",fontsize=14)
ax1.xlabel("Lattitude",fontsize=14)
ax1.title(f"Lattitude vs. Humidity ({current_date}) ",fontsize=15)
ax1.plot()
ax1.savefig(output_data_file + "lattitude_vs_humidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
ax2 = plt
ax2.figure(figsize=(12,6))
ylim_top = clean_city_data["Cloudiness"].max() + 10
ylim_bottom = clean_city_data["Cloudiness"].min() - 5
ax2.scatter(x=clean_city_data["Lat"], y=clean_city_data["Cloudiness"], marker='o')
ax2.ylim(ylim_bottom,ylim_top)
ax2.ylabel("Cloudiness (%)",fontsize=14)
ax2.xlabel("Lattitude",fontsize=14)
ax2.title(f"Lattitude vs. Cloudiness ({current_date}) ",fontsize=15)
ax2.plot()
ax2.savefig(output_data_file + "lattitude_vs_cloudiness.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
ax3 = plt
ax3.figure(figsize=(12,6))
ylim_top = clean_city_data["Wind Speed"].max() + 10
ylim_bottom = clean_city_data["Wind Speed"].min() - 5
ax3.scatter(x=clean_city_data["Lat"], y=clean_city_data["Wind Speed"], marker='o')
ax3.ylim(ylim_bottom,ylim_top)
ax3.ylabel("Wind Speed (mph)",fontsize=14)
ax3.xlabel("Lattitude",fontsize=14)
ax3.title(f"Lattitude vs. Wind Speed ({current_date}) ",fontsize=15)
ax3.plot()
ax3.savefig(output_data_file + "lattitude_vs_windspeed.png")

# %% [markdown]
# ## Linear Regression

# %%
clean_city_northern_hem = clean_city_data[clean_city_data['Lat'] >= 0]
clean_city_southern_hem = clean_city_data[clean_city_data['Lat'] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
ax4 = plt
ax4.figure(figsize=(12,6))
ylim_top = clean_city_northern_hem["Max Temp"].max() + 10
ylim_bottom = clean_city_northern_hem["Max Temp"].min() - 5
xmin = clean_city_northern_hem["Lat"].min()
x_vals = clean_city_northern_hem["Lat"]
y_vals = clean_city_northern_hem["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_vals, y_vals)
line_formula = f'y = {str(round(slope,2))}x + {str(round(intercept,2))}' 
print(line_formula + f" r-value is {round(rvalue,2)}")
ax4.scatter(x=x_vals, y=y_vals, marker='o')
ax4.ylim(ylim_bottom,ylim_top)
ax4.ylabel("Temperature (F)",fontsize=14)
ax4.xlabel("Lattitude",fontsize=14)
ax4.title(f"Lattitude  vs. Max Temperature Northern Hemisphere ({current_date}) ",fontsize=15)
regress_values = x_vals * slope + intercept
plt.plot(x_vals,regress_values,"r-")
plt.annotate(line_formula,(xmin,ylim_bottom + 5),fontsize=15,color="red")
ax4.plot()
ax4.savefig(output_data_file + "lattitude_vs_max_temp_northern_hemisphere.png")
# Out:
# y = -1.37x + 92.41 r-value is -0.88

# %% [markdown]
# *** Lattitude vs Max Temperature Northern Hemisphere***  There is an indirect direct relationship between temperature and lattitude.  The max temperatures of the cities are decreases as distance between city and equator increases, which is supported by the negative slope (-1.37) returned by linregress function.  The correlation is very strong, which is supported by the r-value of .88.  Also, visually it is evident that the cities are densly packed about the plotted line.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
ax5 = plt
ax5.figure(figsize=(12,6))
line1 = plt
ylim_top = clean_city_southern_hem["Max Temp"].max() + 10
ylim_bottom = clean_city_southern_hem["Max Temp"].min() - 5
xmin = clean_city_southern_hem["Lat"].min()
x_vals = clean_city_southern_hem["Lat"]
y_vals = clean_city_southern_hem["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_vals, y_vals)
line_formula = f'y = {str(round(slope,2))}x + {str(round(intercept,2))}'
regress_values = x_vals * slope + intercept
print(line_formula + f" r-value is {round(rvalue,2)}")
ax5.scatter(x=x_vals, y=y_vals, marker='o')
ax5.ylim(ylim_bottom,ylim_top)
ax5.ylabel("Temperature (F)",fontsize=14)
ax5.xlabel("Lattitude",fontsize=14)
ax5.title(f"Lattitude  vs. Max Temperature Southern Hemisphere ({current_date}) ",fontsize=15)

line1.annotate(line_formula,xy=(xmin + 5,ylim_bottom + 5),fontsize=15,color="red")
line1.plot(x_vals,regress_values,"r-")

ax5.savefig(output_data_file + "lattitude_vs_max_temp_southern_hemisphere.png")
# Out:
# y = 0.33x + 81.99 r-value is 0.49

# %% [markdown]
# *** Lattitude vs Max Temperature Southern Hemisphere***  There is direct relationship between temperature and lattitude.  The max temperatures of the cities are incresasing as the lattitude approaches the equator, which is supported by the positive slope (.33) returned by linregress function.  The correlation is not as strong as the northern hemisphere graph, which is supported by the lower r-value of .49

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
ax6 = plt
ax6.figure(figsize=(12,6))
ylim_top = clean_city_northern_hem["Humidity"].max() + 10
ylim_bottom = clean_city_northern_hem["Humidity"].min() - 5
xmin = clean_city_northern_hem["Lat"].min()
x_vals = clean_city_northern_hem["Lat"]
y_vals = clean_city_northern_hem["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_vals, y_vals)
line_formula = f'y = {str(round(slope,2))}x + {str(round(intercept,2))}' 
regress_values = x_vals * slope + intercept
print(line_formula  + f" r-value is {round(rvalue,2)}")
ax6.scatter(x=x_vals, y=y_vals, marker='o')
ax6.ylim(ylim_bottom,ylim_top)
ax6.ylabel("Humidity (%)",fontsize=14)
ax6.xlabel("Lattitude",fontsize=14)
ax6.title(f"Lattitude vs. Humidity Northern Hemisphere ({current_date}) ",fontsize=15)
ax6.plot()
plt.annotate(line_formula,xy=(xmin + 20,ylim_bottom + 5),fontsize=15,color="red")
plt.plot(x_vals,regress_values,"r-")
ax6.savefig(output_data_file + "lattitude_vs_humidity_northern_hemisphere.png")
# Out:
# y = 0.41x + 56.99 r-value is 0.42

# %% [markdown]
# *** Lattitude vs Humidity Northern Hemisphere***  There is a direct relationship between humidity and lattitude, which is supported by the slope of .41 generated by linear regression function. The correlation of the entire data set shows a weak correlation between the two values.  Most likely, due to the humidty variance of the cities between lattitudes 0 to 40 degrees.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
ax6 = plt
ax6.figure(figsize=(12,6))
ylim_top = clean_city_southern_hem["Humidity"].max() + 10
ylim_bottom = clean_city_southern_hem["Humidity"].min() - 5
xmin = clean_city_southern_hem["Lat"].min()
x_vals = clean_city_southern_hem["Lat"]
y_vals = clean_city_southern_hem["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_vals, y_vals)
line_formula = f'y = {str(round(slope,2))}x + {str(round(intercept,2))}' 
regress_values = x_vals * slope + intercept
print(line_formula  + f" r-value is {round(rvalue,2)}")
ax6.scatter(x=x_vals, y=y_vals, marker='o')
ax6.ylim(ylim_bottom,ylim_top)
ax6.ylabel("Humidity (%)",fontsize=14)
ax6.xlabel("Lattitude",fontsize=14)
ax6.title(f"Lattitude vs. Humidity Southern Hemisphere ({current_date}) ",fontsize=15)
ax6.plot()
plt.annotate(line_formula,xy=(xmin + 5,ylim_bottom + 5),fontsize=15,color="red")
plt.plot(x_vals,regress_values,"r-")
ax6.savefig(output_data_file + "lattitude_vs_humidity_southern_hemisphere.png")
# Out:
# y = 0.38x + 82.27 r-value is 0.32

# %% [markdown]
# *** Lattitude vs Humidity Southern Hemisphere***  There is a direct relationship between humidity and lattitude, which is supported by the slope of .41 generated by linear regression function. The correlation of the entire data set shows a weak correlation between the two values.  Most likely, due to the humidty variance of the cities between lattitudes 0 to 40 degrees.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
ax7 = plt
ax7.figure(figsize=(12,6))
ylim_top = clean_city_northern_hem["Cloudiness"].max() + 10
ylim_bottom = clean_city_northern_hem["Cloudiness"].min() - 5
xmin = clean_city_northern_hem["Lat"].min()
x_vals = clean_city_northern_hem["Lat"]
y_vals = clean_city_northern_hem["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_vals, y_vals)
line_formula = f'y = {str(round(slope,2))}x + {str(round(intercept,2))}' 
regress_values = x_vals * slope + intercept
print(line_formula  + f" r-value is {round(rvalue,2)}")
ax7.scatter(x=x_vals, y=y_vals, marker='o')
ax7.ylim(ylim_bottom,ylim_top)
ax7.ylabel("Cloudiness (%)",fontsize=14)
ax7.xlabel("Lattitude",fontsize=14)
ax7.title(f"Lattitude vs. Cloudiness Northern Hemisphere ({current_date}) ",fontsize=15)
ax7.plot()
plt.annotate(line_formula,xy=(xmin + 20,ylim_bottom + 10),fontsize=15,color="red")
plt.plot(x_vals,regress_values,"r-")
ax7.savefig(output_data_file + "lattitude_vs_cloudiness_northern_hemisphere.png")
# Out:
# y = 0.6x + 29.93 r-value is 0.31

# %% [markdown]
# *** Lattitude vs Cloudiness Northern Hemisphere***  There is a direct relationship between cloudiness and lattitude, which is supported by the slope of .6 generated by linear regression function. The correlation of the entire data set shows a very weak correlation between the two values.  It seems that in the northern hemisphere it is either very cloudy or very little clouds.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
ax7 = plt
ax7.figure(figsize=(12,6))
ylim_top = clean_city_southern_hem["Cloudiness"].max() + 10
ylim_bottom = clean_city_southern_hem["Cloudiness"].min() - 5
xmin = clean_city_southern_hem["Lat"].min()
x_vals = clean_city_southern_hem["Lat"]
y_vals = clean_city_southern_hem["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_vals, y_vals)
line_formula = f'y = {str(round(slope,2))}x + {str(round(intercept,2))}' 
regress_values = x_vals * slope + intercept
print(line_formula  + f" r-value is {round(rvalue,2)}")
ax7.scatter(x=x_vals, y=y_vals, marker='o')
ax7.ylim(ylim_bottom,ylim_top)
ax7.ylabel("Cloudiness (%)",fontsize=15)
ax7.xlabel("Lattitude",fontsize=15)
ax7.title(f"Lattitude vs. Cloudiness Southern Hemisphere ({current_date}) ",fontsize=15)
ax7.plot()
plt.annotate(line_formula,xy=(xmin + 20,ylim_bottom + 10),fontsize=15,color="red")
plt.plot(x_vals,regress_values,"r-")
ax7.savefig(output_data_file + "lattitude_vs_cloudiness_southern_hemisphere.png")
# Out:
# y = 0.93x + 70.3 r-value is 0.37

# %% [markdown]
# *** Lattitude vs Cloudiness Southern Hemisphere***  There is a direct relationship between cloudiness and lattitude, which is supported by the slope of .93 generated by linear regression function. The correlation of the entire data set shows a very weak correlation between the two values.  Observing  both northern and southern hemisphere maps it seems that the trend is for the their to be more clouds as as we move north from the antarctic to the artic regions.  This could be due to the season of the year, which the northern hemisphere is experiencing it's colder season as the southern hemisphere is enjoying warmer weather.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
ax8 = plt
ax8.figure(figsize=(12,6))
ylim_top = clean_city_northern_hem["Wind Speed"].max() + 10
ylim_bottom = clean_city_northern_hem["Wind Speed"].min() - 5
xmin = clean_city_northern_hem["Lat"].min()
x_vals = clean_city_northern_hem["Lat"]
y_vals = clean_city_northern_hem["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_vals, y_vals)
line_formula = f'y = {str(round(slope,2))}x + {str(round(intercept,2))}' 
regress_values = x_vals * slope + intercept
print(line_formula  + f" r-value is {round(rvalue,2)}")
ax8.scatter(x=x_vals, y=y_vals, marker='o')
ax8.ylim(ylim_bottom,ylim_top)
ax8.ylabel("Wind Speed (%)",fontsize=14)
ax8.xlabel("Lattitude",fontsize=14)
ax8.title(f"Lattitude vs. Wind Speed Northern Hemisphere ({current_date}) ",fontsize=15)
ax8.plot()
plt.annotate(line_formula,xy=(xmin + 20,ylim_top - 10),fontsize=15,color="red")
plt.plot(x_vals,regress_values,"r-")
ax8.savefig(output_data_file + "lattitude_vs_windspeed_northern_hemisphere.png")
# Out:
# y = 0.02x + 8.67 r-value is 0.07

# %% [markdown]
# ***Lattiude vs Wind Speed Northern Hemisphere *** There seems to any noticible change in wind speed as we move from the equater to the acrtic region.  The rate of change seems to be stagnant, which is evident by the slope of .02 returned by the lineregress function.  The r-value .07 depicts a no meanningful correlation between wind speed and lattitude.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
ax8 = plt
ax8.figure(figsize=(12,6))
ylim_top = clean_city_southern_hem["Wind Speed"].max() + 10
ylim_bottom = clean_city_southern_hem["Wind Speed"].min() - 5
xmin = clean_city_southern_hem["Lat"].min()
x_vals = clean_city_southern_hem["Lat"]
y_vals = clean_city_southern_hem["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_vals, y_vals)
line_formula = f'y = {str(round(slope,2))}x + {str(round(intercept,2))}' 
regress_values = x_vals * slope + intercept
print(line_formula  + f" r-value is {round(rvalue,2)}")
ax8.scatter(x=x_vals, y=y_vals, marker='o')
ax8.ylim(ylim_bottom,ylim_top)
ax8.ylabel("Wind Speed (%)",fontsize=14)
ax8.xlabel("Lattitude",fontsize=14)
ax8.title(f"Lattitude vs. Wind Speed Southern Hemisphere ({current_date}) ",fontsize=15)
ax8.plot()
plt.annotate(line_formula,xy=(xmin + 20,ylim_top - 10),fontsize=15,color="red")
plt.plot(x_vals,regress_values,"r-")
ax8.savefig(output_data_file + "lattitude_vs_windspeed_southern_hemisphere.png")
# Out:
# y = -0.1x + 6.62 r-value is -0.22

# %% [markdown]
# ***Lattiude vs Wind Speed Northern Hemisphere *** There is a slight inverse relationship between wind speed and lattitude.  AS we move from the south to the equator, the wind speed seems to decrease, which is supported by the slope of .10. The r-value .22 depicting a very weak correlation between wind speed and lattitude.
